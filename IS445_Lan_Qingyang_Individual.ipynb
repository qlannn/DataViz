# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# to use interactivity
import ipywidgets

# %%
data_url = 'https://raw.githubusercontent.com/qlannn/cvs/main/2018.csv'
df = pd.read_csv(data_url, encoding='latin1')

# %% [markdown]
# # An analysis of the happiness index for the years 2018 and 2019

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
data_url = 'https://raw.githubusercontent.com/qlannn/cvs/main/2019.csv'
df = pd.read_csv(data_url, encoding='latin1')

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
data_url = 'https://raw.githubusercontent.com/qlannn/cvs/main/report_2018-2019.csv'
df = pd.read_csv(data_url, encoding='latin1')

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
#  This data set has three main files. I've put their dataset out and you can see exactly how many fields/columns/rows there are. The purpose of this study was to investigate the impact of these variables on happiness scores in 2018 and 2019. In addition, the differences in happiness between different countries can also be reflected in the data set.

# %%
print(df.dtypes)
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %% [markdown]
# What is the "name" of the dataset?
# Happiness Index 2018-2019

# %% [markdown]
# Where did you obtain it?
# From kaggle

# %% [markdown]
# Where can we obtain it? (i.e., URL)
# https://www.kaggle.com/datasets/sougatapramanick/happiness-index-2018-2019

# %% [markdown]
# What is the license of the dataset? What are we allowed to do with it?
# Public and License
# Other (specified in description)

# %% [markdown]
# How big is it in file size and in items?
# About 16kb

# %%
import matplotlib.pyplot as plt

data = df[['Healthy life expectancy', 'Score']]

plt.scatter(data['Healthy life expectancy'], data['Score'], alpha=0.5)
plt.title('Relationship between Healthy life expectancy and Score')
plt.xlabel('Healthy life expectancy')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# This data visualization example illustrates the impact of Healthy life expectancy on happiness scores

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')
